# %% [markdown]
# # Vectores

# %%
v=[1,2,3]
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
w
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
v⋅w
# Out:
# 14

# %% [markdown]
# Los arreglos se pueden considerar simplemente como secuencias de números, es decir, un tipo de *contenedor* que contienen datos.
#
# Sin embargo, en la física, usamos colecciones de números con otra meta: *representar* a las componentes de vectores matemáticos.
#
# Resulta que en Julia, podemos utilizar arreglos ¡también para este fin!
#
# [1] Define dos vectores `v` y `w` con tres componentes cada quien.
#
# [2] Intenta calcular dos veces `v`,  y la suma de `v` y `w`. ¿Funciona como esperarías?
#
# [3] Adivina cómo se llaman las funciones de producto punto y cruz, y verifica que funcionan.
#
# [4] Estas funciones también se pueden escribir con `\cdot` y `\times`,  respectivamente. Inténtalo.
#
# [5] ¿Qué pasa si intentas multiplicar `v` y `w`? ¿Por qué?

# %% [markdown]
# # Operaciones sobre vectores

# %% [markdown]
# Hay muchas operaciones que por conveniencia ya están definidas para que operen sobre vectores. Normalmente las operaciones son *componente por componente*.
#
# Las operaciones aritméticas que funcionen elemento de elemento, aparte de `+` y `-` y multiplicación por un escalar, se escriben con un `.` antes de la operación. Por ejemplo, podemos dividir dos vectores elemento por elemento así:

# %%
v = [3,4,5]
w = [6,7,8]
# Out:
# 3-element Array{Int64,1}:
#  6
#  7
#  8

# %%
v ⋅ w
# Out:
# 86

# %% [markdown]
# [1] Define una función `producto_punto` que hace tu propio producto punto de dos vectores.

# %%
function dotprod(v,w)
    sum(v.*w)
end
# Out:
# dotprod (generic function with 1 method)

# %%
dotprod(v,w)
# Out:
# 86

# %% [markdown]
# Muchas operaciones matemáticas también están definidas, y operan elemento por elemento:

# %%
v = [3, 4, 5]
sin(v)
# Out:
# 3-element Array{Float64,1}:
#   0.14112
#  -0.756802
#  -0.958924

# %% [markdown]
# [2] Dibuja en una sola gráfica las funciones $\sin$, $\cos$, $2 \sin$, $\sin^2$ y $\frac{1}{2} \cos$
#
# [3] Encuentra gráficamente la solución de la ecuación $\tan(x) = x$.

# %%
x =[-1+1/100*i for i in 0:200];

# %%
f1 = sin(x);
f2 = cos(x);
f3 = sin(x).*sin(x);
f4 = .5.*cos(x);

# %%
Pkg.add("PyPlot")
# Out:
# INFO: Cloning cache of Color from git://github.com/JuliaLang/Color.jl.git
# INFO: Cloning cache of Dates from git://github.com/quinnj/Dates.jl.git
# INFO: Cloning cache of FixedPointNumbers from git://github.com/JeffBezanson/FixedPointNumbers.jl.git
# INFO: Cloning cache of LaTeXStrings from git://github.com/stevengj/LaTeXStrings.jl.git
# INFO: Cloning cache of PyCall from git://github.com/stevengj/PyCall.jl.git
# INFO: Cloning cache of PyPlot from git://github.com/stevengj/PyPlot.jl.git
# INFO: Installing Color v0.3.15
# INFO: Installing Dates v0.3.2
# INFO: Installing FixedPointNumbers v0.0.6
# INFO: Installing LaTeXStrings v0.1.2
# INFO: Installing PyCall v0.7.3
# INFO: Installing PyPlot v1.5.1
# INFO: Package database updated
# INFO: METADATA is out-of-date — you may not have the latest version of PyPlot
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
plot(x,f1,x,f2,x,f3,x,f4)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fd100be8e90>)
# 4-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fd1009a2b50>
#  PyObject <matplotlib.lines.Line2D object at 0x7fd1009a2dd0>
#  PyObject <matplotlib.lines.Line2D object at 0x7fd1009af4d0>
#  PyObject <matplotlib.lines.Line2D object at 0x7fd1009afb10>

# %%
plot(x,tan(x),x,x)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fd100768dd0>)
# 2-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fd1006f8b10>
#  PyObject <matplotlib.lines.Line2D object at 0x7fd1006f8d90>
